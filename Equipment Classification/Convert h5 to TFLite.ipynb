# %%
import tensorflow as tf

# %%
# Load model .h5
model_eqp = tf.keras.models.load_model('equipments.h5')

# Convert to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model_eqp)
tflite_model = converter.convert()

with open('equipments_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("Succes")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved artifact at '/tmp/tmpl0s_pxes'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   138503552622736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138503552880128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138503552882240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138503552629600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138503552877840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138503552884880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138503552885232: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
